# %%
#%pip install pynput

# %%
#%pip install pyautogui

# %%
#!pip install pydirectinput

# %%
import cv2
import numpy as np
import random
import pydirectinput
import time

# Load reference images
image_paths = [
    "Screenshot 2024-12-16 154156.png" ,
    "Screenshot 2024-12-16 185345.png" ,
   
]
# ref 1 (X) : Screenshot 2024-12-16 154156.png , purple
# ref 2 (Y) : Screenshot 2024-12-16 185345.png , blue 
# ref 3 (Z) : Screenshot 2024-12-16 185500.png , yellow
# ref 4 (V) : Screenshot 2024-12-16 185542.png , red
def process_and_locate(image_paths, screenshot, scales=(0.4,0.45, 0.5,0.55,0.6,0.65 , 0.7 , 0.75 , 0.8 , 0.85 , 0.9 ,0.95 , 1.0)):
    """
    Process the screenshot and locate the position of the game window based on reference images.
    Save the minimum threshold smaller than 0.3 and return its game location.
    """
    
    
    reference_images_data = []
    
    for i, path in enumerate(image_paths, start=1):
        ref_image = cv2.imread(path)
        if ref_image is not None:
            label = f"Game Screen {i}"
            reference_images_data.append({"image": ref_image, "label": label})
        else:
            print(f"Error: Could not load {path}")
    
    gray_screenshot = cv2.cvtColor(screenshot, cv2.COLOR_BGR2GRAY)
    threshold = 0.31
    min_threshold = float('inf')  # Variable to store the smallest threshold
    best_game_location = None  # Variable to store the best game location
    
    for ref in reference_images_data:
        for scale in scales:
            scaled_ref = cv2.resize(ref["image"], None, fx=scale, fy=scale, interpolation=cv2.INTER_AREA)
            result = cv2.matchTemplate(screenshot, scaled_ref, cv2.TM_SQDIFF_NORMED)
            min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
            print(f"[DEBUG] Match results for {ref['label']}: Min Val={min_val} , Max Val={max_val}, Min Loc={min_loc}")
            
            if min_val < min_threshold and min_val < threshold:  # Check if this is the new minimum
                min_threshold = min_val
                best_game_location = (min_loc[0], min_loc[1], scaled_ref.shape[1], scaled_ref.shape[0])
    
    # If a valid game location was found, return it
    if best_game_location:
        print(f"[DEBUG] Minimum threshold: {min_threshold}")
        return best_game_location
    
    return None


def move_character(direction):
    """
    Simulate key presses to move the character left or right.
    """
    if direction == "left":
        pydirectinput.press('left')  # Simulates pressing the Left Arrow key
        print("Moving Left")
        
    elif direction == "right":
        pydirectinput.press('right')  # Simulates pressing the Right Arrow key
        print("Moving Right")

def auto_play(image_path):
    # Load the provided image
    screenshot = cv2.imread(image_path)
    if screenshot is None:
        print(f"Error: Could not load image at path {image_path}")
        return
    
    last_press_time = time.time()  # Track the time of the last press
    
    
        # Locate the game window
    
    game_location = process_and_locate(image_paths, screenshot)
    
    # If game location is found, extract and display the region
    if game_location:
        x, y, w, h = game_location
        
        # Draw a green rectangle around the matched template
        cv2.rectangle(screenshot, (x, y), (x + w, y + h), (0, 255, 0), 2)
        print(f"Drawing rectangle at: x={x}, y={y}, w={w}, h={h}")
        
        # Display the updated screenshot with the rectangle
        screenshot = cv2.resize(screenshot , (900 , 700))
        cv2.imshow("Game Screen", screenshot)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        # Check if it's time to press a key
        current_time = time.time()
        # if current_time - last_press_time >= 0.5:  # 0.5-second delay
        #     direction = random.choice(["left", "right"])
        #     move_character(direction)
        #     last_press_time = current_time  # Reset the timer
    else:
        print("Game window not found!")
    
    
    # Exit the loop if 'q' is pressed
    
        


# Main function to run the auto-play feature
if __name__ == "__main__":
    # Replace this with the path of the image you want to use
    image_path = "C:\\Users\\mayar\\Pictures\\Screenshots\\test_size7.png"
    #Screenshot 2024-12-25 175835.png V
    #Screenshot 2024-12-25 175914.png V 
    #Screenshot 2024-12-25 175856.png X Y Z V size
    #Screenshot 2024-12-25 175931.png X Y Z V
    #Screenshot 2024-12-25 175944.png X Y Z V
    
    # sized photos
    #size1 min val = 4
    #size2 min val = 4.8
    #size3 min val = 1.9
    #size4 min val = 3.2
    #size5 min val = 1.8 
    # tested sized photos
    #test_size1
    #test_size2
    #test_size3
    #test_size7 habaed

    
    """_summary_ there is a problem in red color refrence and there is a problem in size the first and second screen its give me a match but a low match 
    so the color is problem 
    """
    auto_play(image_path)
# Out:
# Error: Could not load image at path C:\Users\mayar\Pictures\Screenshots\test_size7.png

# %%
import cv2

# Load the image in color mode
path = 'C:\\Users\\mayar\\Pictures\\Screenshots\\Screenshot 2024-12-25 175957.png'
image = cv2.imread(path)

# Convert the image to grayscale to determine threshold
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply binary threshold
_, binary_image = cv2.threshold(gray_image, 128, 255, cv2.THRESH_BINARY)

# Apply the binary image as a mask on the original image
masked_image = cv2.bitwise_and(image, image, mask=binary_image)

# Convert the masked image to grayscale
final_gray_image = cv2.cvtColor(masked_image, cv2.COLOR_BGR2GRAY)

# Display the result (for testing purposes)
final_gray_image = cv2.resize(final_gray_image , (1100 , 700))
cv2.imshow("Binary Threshold + Grayscale", final_gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread('C:\\Users\\mayar\\Pictures\\Screenshots\\color12.png')  # Replace with your image path
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Extract the Hue channel
hue_channel = hsv[:, :, 0]

# Calculate the histogram of the Hue channel
hist = cv2.calcHist([hue_channel], [0], None, [180], [0, 180])

# Find the most frequent Hue value
most_frequent_hue = np.argmax(hist)

# Define a range around the most frequent hue (e.g., for crimson, adjust if needed)
hue_range =160  # Range around the most frequent hue
lower_bound = np.array([most_frequent_hue - hue_range, 50, 50])  # Adjust saturation and value as needed
upper_bound = np.array([most_frequent_hue + hue_range, 255, 255])

# Create a mask for the target color
mask = cv2.inRange(hsv, lower_bound, upper_bound)

# Replace the target color with white
result = img.copy()
result[mask > 0] = [255, 255, 255]  # Set to white in BGR

# Display the results
cv2.imshow("Original Image", img)
cv2.imshow("Masked Image", mask)
cv2.imshow("Result Image", result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread('C:\\Users\\mayar\\Pictures\\Screenshots\\color12.png')  # Replace with your image path
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for matplotlib

# Calculate histograms for each channel
colors = ('r', 'g', 'b')  # Color names
for i, color in enumerate(colors):
    hist = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(hist, color=color)
    plt.xlim([0, 256])

plt.title('Color Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.show()

# %%
import cv2
import numpy as np

# Load the image
img = cv2.imread('C:\\Users\\mayar\\Pictures\\Screenshots\\color12.png')  # Replace 'image.jpg' with your image path

# Convert to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Extract the H, S, and V channels
h, s, v = cv2.split(hsv)

# Reduce the Value (V) channel
reduction_amount = 35  # Adjust this value to control brightness reduction
v = np.clip(v - reduction_amount, 0, 255)  # Ensure values remain in [0, 255]

# Merge the channels back
hsv_reduced = cv2.merge([h, s, v])

# Convert back to BGR
img_reduced_brightness = cv2.cvtColor(hsv_reduced, cv2.COLOR_HSV2BGR)

# Display the result
cv2.imshow('Original Image', img)
cv2.imshow('Reduced Brightness', img_reduced_brightness)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # *the code*

# %%
import cv2
import numpy as np
import random
import pydirectinput
import mss
import time
from pynput import keyboard
import matplotlib.pyplot as plt

# %%
def process_and_locate(image_paths, screenshot, scales=(0.4,0.45, 0.5,0.55,0.6,0.65 , 0.7 , 0.75 , 0.8 , 0.85 , 0.9 ,0.95 , 1.0)):
    """
    Process the screenshot and locate the position of the game window based on reference images.
    Save the minimum threshold smaller than 0.3 and return its game location.
    """
    
    
    reference_images_data = []
    
    for i, path in enumerate(image_paths, start=1):
        ref_image = cv2.imread(path)
        if ref_image is not None:
            label = f"Game Screen {i}"
            reference_images_data.append({"image": ref_image, "label": label})
        else:
            print(f"Error: Could not load {path}")
    
    gray_screenshot = cv2.cvtColor(screenshot, cv2.COLOR_BGR2GRAY)
    threshold = 0.31
    min_threshold = float('inf')  # Variable to store the smallest threshold
    best_game_location = None  # Variable to store the best game location
    
    for ref in reference_images_data:
        for scale in scales:
            scaled_ref = cv2.resize(ref["image"], None, fx=scale, fy=scale, interpolation=cv2.INTER_AREA)
            result = cv2.matchTemplate(screenshot, scaled_ref, cv2.TM_SQDIFF_NORMED)
            min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
            #print(f"[DEBUG] Match results for {ref['label']}: Min Val={min_val} , Max Val={max_val}, Min Loc={min_loc}")
            
            if min_val < min_threshold and min_val < threshold:  # Check if this is the new minimum
                min_threshold = min_val
                best_game_location = (min_loc[0], min_loc[1], scaled_ref.shape[1], scaled_ref.shape[0])
    
    # If a valid game location was found, return it
    if best_game_location:
        print(f"[DEBUG] Minimum threshold: {min_threshold}")
        return best_game_location
    
    return None

# %%
def move_character(direction):
    """
    Simulate key presses to move the character left or right.
    """
    if direction == "left":
        pydirectinput.press('left')  # Simulates pressing the Left Arrow key
        print("Moving Left")
        
    elif direction == "right":
        pydirectinput.press('right')  # Simulates pressing the Right Arrow key
        print("Moving Right")

# %%
LEFT_ROI = None
RIGHT_ROI = None
CENTER_ROI = None

def locate_player_and_define_rois(frame_left, frame_right, character_template):
    """
    Locate the player in the given frames using template matching and define three ROIs:
    - Left ROI from the left image.
    - Right ROI from the right image.
    - Center ROI based on the template's head position.

    Parameters:
        frame_left (np.ndarray): The input frame where the character is on the left.
        frame_right (np.ndarray): The input frame where the character is on the right.
        character_template (np.ndarray): The template image of the character.

    Returns:
        None: Updates the global variables LEFT_ROI, RIGHT_ROI, CENTER_ROI.
    """
    global LEFT_ROI, RIGHT_ROI, CENTER_ROI

    def get_roi(frame, template_gray, position):
        # Convert frame to grayscale
        frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Get dimensions of the template
        template_height, template_width = template_gray.shape
        extra_height = 1.5 * template_height
        adjusted_height = int(template_height + extra_height)

        # Perform template matching
        result = cv2.matchTemplate(frame_gray, template_gray, cv2.TM_CCOEFF_NORMED)
        _, _, _, top_left = cv2.minMaxLoc(result)

        # Define the ROI
        x = top_left[0]
        y = max(0, top_left[1] - int(extra_height))
        w = template_width
        h = adjusted_height
        roi_coords = (x, y, w, h)

        print(f"{position.capitalize()} ROI Coordinates: x={x}, y={y}, w={w}, h={h}")
        return roi_coords

    # Convert template to grayscale
    template_gray = cv2.cvtColor(character_template, cv2.COLOR_BGR2GRAY)

    # Get left ROI from the left frame
    LEFT_ROI = get_roi(frame_left, template_gray, "left")

    # Get right ROI from the right frame
    RIGHT_ROI = get_roi(frame_right, template_gray, "right")

    # Get center ROI (based on template's head position in the left frame)
    template_height, template_width = template_gray.shape
    center_x = LEFT_ROI[0]  # Start after the template's head
    center_y = LEFT_ROI[1]
    center_w = template_width * 4
    center_h = template_height
    CENTER_ROI = (center_x, center_y, center_w, center_h)
    print(f"Center ROI Coordinates: x={center_x}, y={center_y}, w={center_w}, h={center_h}")

# %%
character_template = cv2.imread("player.png")
frame_left = cv2.imread("left.png")
frame_right = cv2.imread("right.png")
locate_player_and_define_rois(frame_left , frame_right , character_template)
# Out:
# Left ROI Coordinates: x=187, y=402, w=53, h=207
# Right ROI Coordinates: x=327, y=406, w=53, h=207
# Center ROI Coordinates: x=187, y=402, w=212, h=83

# %%
def detect_branches(mask, original_image):
    """
    Detect branches using the given mask and return their locations.
    
    Parameters:
        mask (np.ndarray): Binary mask highlighting the tree trunk and branches.
        original_image (np.ndarray): Original image for coordinate adjustment.

    Returns:
        list: A list of branch lines, each represented as (x1, y1, x2, y2).
    """
    # Apply Gaussian Blur to reduce noise
    blurred_mask = cv2.GaussianBlur(mask, (5, 5), 0)
    
    # Edge detection using Canny
    edges = cv2.Canny(blurred_mask, 100, 150)
    
    # Detect horizontal lines using Hough Line Transform
    lines = cv2.HoughLinesP(edges, 1, np.pi / 180, threshold=50, minLineLength=30, maxLineGap=10)
    
    branches = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            if abs(y2 - y1) < 10:  # Only keep horizontal lines
                branches.append((x1, y1, x2, y2))
                # Draw the detected branches on the original image for visualization
                cv2.line(original_image, (x1, y1), (x2, y2), (0, 255, 0), 2)
    return branches

def detect_branches_in_roi_hough(frame, roi_coords):
    """
    Detect branches in the ROI of the frame using Hough Lines and visualize processing steps.

    Parameters:
        frame (np.ndarray): The input frame where branches will be detected.
        roi_coords (tuple): Coordinates of the ROI as (x, y, w, h).

    Returns:
        frame_with_branches (np.ndarray): The frame with detected branches and ROI bounding box drawn.
        branches (list): A list of detected branch line segments as (x1, y1, x2, y2).
    """
    # Extract ROI from the frame
    x, y, w, h = roi_coords
    roi = frame[y:y + h, x:x + w]

    # Convert ROI to grayscale
    roi_gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)

    # Apply binary thresholding
    _, roi_thresh = cv2.threshold(roi_gray, 70, 255, cv2.THRESH_BINARY_INV)

    # Refine the mask using morphological operations
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (7, 7))
    roi_refined = cv2.morphologyEx(roi_thresh, cv2.MORPH_CLOSE, kernel)

    # Detect branches using the Hough Line-based function
    branches = detect_branches(roi_refined, roi)
    
    if branches is not None:
        print(f"Branches detected in ROI: {roi_coords}")
        return True
    print(f"No branches detected in ROI: {roi_coords}")
    return False

# %%
def game_loop(frame):
    """
    Main game loop to move the character and detect branches.
    The game always starts with the character on the left.

    Parameters:
        frame (np.ndarray): The input frame where branch detection is performed.
    """
    global LEFT_ROI, RIGHT_ROI

    # Start by moving the character to the left
    move_character("left")
    searching_in_left = True  # Start with searching in the left ROI

    while True:
        if searching_in_left:
            if detect_branches_in_roi_hough(frame, LEFT_ROI):
                move_character("right")
                searching_in_left = False  # Switch to searching in the right ROI
        else:
            if detect_branches_in_roi_hough(frame, RIGHT_ROI):
                move_character("left")
                searching_in_left = True  # Switch to searching in the left ROI

# %%
def apply_binary_mask (img):
    # Convert to HSV
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hue_channel = hsv[:, :, 0]  # Extract the Hue channel

    # Normalize the Hue values to the full range [0, 255]
    hue_normalized = cv2.normalize(hue_channel, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
    cv2.imshow('hue_normalize' , hue_normalized)
    cv2.waitKey(0)
    # # Remove yellow regions
    # lower_yellow = np.array([20, 100, 100])
    # upper_yellow = np.array([30, 255, 255])
    # yellow_mask = cv2.inRange(hsv, lower_yellow, upper_yellow)

    # Threshold the black areas in the Hue channel
    _, black_mask = cv2.threshold(hue_normalized, 19, 255, cv2.THRESH_BINARY_INV)

    # Refine the mask with morphological operations
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (13, 13))
    black_mask_refined = cv2.morphologyEx(black_mask, cv2.MORPH_OPEN, kernel)  # Remove small noise
    black_mask_refined = cv2.morphologyEx(black_mask_refined, cv2.MORPH_CLOSE, kernel)  # Fill small gaps

    # Apply Gaussian Blur to smooth the edges
    black_mask_smooth = cv2.GaussianBlur(black_mask_refined, (5, 5), 0)
    return black_mask_smooth

# %%
image_paths = [
    "Screenshot 2024-12-16 154156.png" ,
    
   
]

# %%
player_temp = cv2.imread('player.png')

# %%
# not used 

def reduce_image_brightness_preserve_black(img, reduction_factor=0.4):
    """
    Reduces the brightness of an image by scaling the Value (V) channel in HSV,
    preserving dark tones and avoiding white overexposure.

    Parameters:
        img (numpy.ndarray): The input image in BGR format.
        reduction_factor (float): The scaling factor for brightness (0 < reduction_factor <= 1).
                                  A value closer to 1 reduces brightness less.
        
    Returns:
        numpy.ndarray: The resulting image with reduced brightness.
    """
    # Convert the image to HSV
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    # Extract the H, S, and V channels
    h, s, v = cv2.split(hsv)
    
    # Scale the Value (V) channel while maintaining the dark tones
    v = (v * reduction_factor).astype(np.uint8)  # Scale and cast back to uint8
    
    # Merge the channels back
    hsv_reduced = cv2.merge([h, s, v])
    
    # Convert back to BGR
    img_reduced_brightness = cv2.cvtColor(hsv_reduced, cv2.COLOR_HSV2BGR)
    
    return img_reduced_brightness

# %% [markdown]
#  ### next cell for test only , without mss real time

# %%
path = 'C:\\Users\\mayar\\Pictures\\Screenshots\\color5.png'
#color1.png 1-> 20
#level 1 problem 2 ,  
#level 2 problem 6 , 
#level 3 problem 4 , 5 , 8 , 12 , 19 
#NOTE : 1- sun is bad , 2- moon is good
#NOTE : dark is good , red is bad , 
img = cv2.imread(path)
img = cv2.resize(img , (616 , 813))
img = reduce_image_brightness_preserve_black(img)
cv2.imshow('0' , img)
cv2.waitKey(0)
img , croods = locate_player_and_define_roi(img , player_temp )
cv2.imshow('1' , img)
cv2.waitKey(0)
mx = apply_binary_mask(img)
cv2.imshow('m' , mx)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def capture_screenshot(monitor):
    with mss.mss() as sct:
        screenshot = np.array(sct.grab(monitor))
        return cv2.cvtColor(screenshot, cv2.COLOR_BGRA2BGR)


def on_press(key):
    global game_location
    try:
        if key.char == 'r':  
            print("[INFO] 'R' key pressed. Searching for the game window...")
            game_location = None  # Reset the game location
    except AttributeError:
        pass

# Main function for game processing
def stream_game_region():
    global monitor, running, game_location
    global LEFT_ROI, RIGHT_ROI, CENTER_ROI

    while running:
        # Capture a screenshot
        screenshot = capture_screenshot(monitor)
        
        if game_location is None:
            # Attempt to locate the game window
            game_location = process_and_locate(image_paths, screenshot)
            game_is_running = False
        
        if game_location:
            x, y, w, h = game_location

            # Extract and stream the game region
            game_region = screenshot[y:y + h, x:x + w]
            game_region = cv2.resize(game_region , (616 , 813))
            
            if all(roi is not None for roi in [LEFT_ROI, RIGHT_ROI, CENTER_ROI]):
                x1 , y1 , w1 , h1 = LEFT_ROI
                x2 , y2 , w2 , h2 = RIGHT_ROI
                x3 , y3 , w3 , h3 = CENTER_ROI
                roi_region_left = game_region[y1:y1 + h1, x1:x1 + w1]
                roi_region_right = game_region[y2:y2 + h2, x2:x2 + w2]
                roi_region_center = game_region[y3:y3 + h3, x3:x3 + w3]
            
                if not game_is_running :
                    cv2.imshow("roi left" , roi_region_left)
                    cv2.imshow("roi right", roi_region_right)
                    cv2.imshow("roi center", roi_region_center)
                    game_is_running = True
                cv2.imshow("Game Screen", game_region)
                game_loop(game_region)
        else:
            # Display black screen with "Game Not Found" text
            black_screen = np.zeros((700, 900, 3), dtype=np.uint8)
            cv2.putText(black_screen, "Game Not Found", (250, 350), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 0, 255), 3)
            cv2.imshow("Game Screen", black_screen)

        # Check for key press to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            print("[INFO] 'Q' key pressed. Exiting...")
            running = False
            break

# %% [markdown]
# ### *main cell*

# %%
with mss.mss() as sct:
    monitor = sct.monitors[1]  # Use the primary monitor

# Reference images for matching

# Initialize global variables
game_location = None
running = True

# Start keyboard listener
listener = keyboard.Listener(on_press=on_press)
listener.start()

print("[INFO] Press 'R' to locate the game window.")
print("[INFO] Press 'Q' to quit the script.")

# Start streaming the game region
try:
    stream_game_region()
except KeyboardInterrupt:
    print("[INFO] Script interrupted.")
finally:
    # Cleanup resources
    cv2.destroyAllWindows()
    listener.stop()
    print("[INFO] Script terminated.")
# Out:
# [INFO] Press 'R' to locate the game window.
# [INFO] Press 'Q' to quit the script.
# [DEBUG] Match results for Game Screen 1: Min Val=0.551895260810852 , Max Val=1.0, Min Loc=(88, 572)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5815324783325195 , Max Val=1.0, Min Loc=(110, 559)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6124520897865295 , Max Val=1.0, Min Loc=(13, 585)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6098682284355164 , Max Val=1.0, Min Loc=(25, 571)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6333642601966858 , Max Val=1.0, Min Loc=(13, 557)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6689652800559998 , Max Val=1.0, Min Loc=(0, 510)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7221338748931885 , Max Val=1.0, Min Loc=(0, 471)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7553861141204834 , Max Val=1.0, Min Loc=(0, 8)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7525995373725891 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7682207226753235 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7855979800224304 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.786511242389679 , Max Val=1.0, Min Loc=(0, 2)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7854642271995544 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.551895260810852 , Max Val=1.0, Min Loc=(88, 572)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5815325975418091 , Max Val=1.0, Min Loc=(110, 559)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6124517917633057 , Max Val=1.0, Min Loc=(13, 585)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6098682284355164 , Max Val=1.0, Min Loc=(25, 571)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6333643794059753 , Max Val=1.0, Min Loc=(13, 557)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6690763235092163 , Max Val=1.0, Min Loc=(0, 510)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7224931716918945 , Max Val=1.0, Min Loc=(0, 471)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7535601258277893 , Max Val=1.0, Min Loc=(0, 8)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7516501545906067 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7708432078361511 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7913592457771301 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7946668863296509 , Max Val=1.0, Min Loc=(0, 1)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7977608442306519 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.551895260810852 , Max Val=1.0, Min Loc=(88, 572)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5815327763557434 , Max Val=1.0, Min Loc=(110, 559)
# [DEBUG] Match results for Game Screen 1: Min Val=0.612199604511261 , Max Val=1.0, Min Loc=(13, 587)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6151554584503174 , Max Val=1.0, Min Loc=(25, 570)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6504769325256348 , Max Val=1.0, Min Loc=(1, 537)
# [DEBUG] Match results for Game Screen 1: Min Val=0.6981343626976013 , Max Val=1.0, Min Loc=(0, 509)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7493533492088318 , Max Val=1.0, Min Loc=(0, 332)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7536675333976746 , Max Val=1.0, Min Loc=(0, 8)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7525051832199097 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7697449922561646 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7875163555145264 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7881156206130981 , Max Val=1.0, Min Loc=(0, 1)
# [DEBUG] Match results for Game Screen 1: Min Val=0.7892137169837952 , Max Val=1.0, Min Loc=(0, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.8145550489425659 , Max Val=1.0, Min Loc=(996, 350)
# [DEBUG] Match results for Game Screen 1: Min Val=0.813168466091156 , Max Val=1.0, Min Loc=(961, 320)
# [DEBUG] Match results for Game Screen 1: Min Val=0.8312860131263733 , Max Val=1.0, Min Loc=(929, 290)
# [DEBUG] Match results for Game Screen 1: Min Val=0.8378298878669739 , Max Val=1.0, Min Loc=(961, 345)
# [DEBUG] Match results for Game Screen 1: Min Val=0.8491111993789673 , Max Val=1.0, Min Loc=(1008, 293)
# [DEBUG] Match results for Game Screen 1: Min Val=0.8611468076705933 , Max Val=1.0, Min Loc=(961, 293)
# [DEBUG] Match results for Game Screen 1: Min Val=0.8631274700164795 , Max Val=1.0, Min Loc=(961, 340)
# [DEBUG] Match results for Game Screen 1: Min Val=0.8680166602134705 , Max Val=1.0, Min Loc=(970, 281)
# [DEBUG] Match results for Game Screen 1: Min Val=0.88173508644104 , Max Val=1.0, Min Loc=(961, 383)
# [DEBUG] Match results for Game Screen 1: Min Val=0.8819735050201416 , Max Val=1.0, Min Loc=(960, 325)
# [DEBUG] Match results for Game Screen 1: Min Val=0.8840869069099426 , Max Val=1.0, Min Loc=(961, 297)
# [DEBUG] Match results for Game Screen 1: Min Val=0.9144284725189209 , Max Val=1.0, Min Loc=(942, 249)
# [DEBUG] Match results for Game Screen 1: Min Val=0.9259364008903503 , Max Val=1.0, Min Loc=(922, 0)
# [DEBUG] Match results for Game Screen 1: Min Val=0.4760057330131531 , Max Val=1.0, Min Loc=(1254, 346)
# [DEBUG] Match results for Game Screen 1: Min Val=0.4808403551578522 , Max Val=1.0, Min Loc=(1242, 314)
# [DEBUG] Match results for Game Screen 1: Min Val=0.48472994565963745 , Max Val=1.0, Min Loc=(1156, 189)
# [DEBUG] Match results for Game Screen 1: Min Val=0.49381712079048157 , Max Val=1.0, Min Loc=(1168, 168)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5154586434364319 , Max Val=1.0, Min Loc=(1276, 168)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5449782013893127 , Max Val=1.0, Min Loc=(1192, 168)
# [DEBUG] Match results for Game Screen 1: Min Val=0.550416886806488 , Max Val=1.0, Min Loc=(1122, 248)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5573530793190002 , Max Val=1.0, Min Loc=(1139, 221)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5512168407440186 , Max Val=1.0, Min Loc=(1126, 199)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5443342924118042 , Max Val=1.0, Min Loc=(1116, 177)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5666185021400452 , Max Val=1.0, Min Loc=(958, 168)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5779050588607788 , Max Val=1.0, Min Loc=(1025, 168)
# [DEBUG] Match results for Game Screen 1: Min Val=0.5724387168884277 , Max Val=1.0, Min Loc=(989, 168)
# [DEBUG] Match results for Game Screen 1: Min Val=0.30266210436820984 , Max Val=1.0, Min Loc=(1261, 168)
# [DEBUG] Match results for Game Screen 1: Min Val=0.3417268395423889 , Max Val=1.0, Min Loc=(1252, 169)
# [DEBUG] Match results for Game Screen 1: Min Val=0.3616558313369751 , Max Val=1.0, Min Loc=(1244, 168)
# [DEBUG] Match results for Game Screen 1: Min Val=0.3863806128501892 , Max Val=1.0, Min Loc=(1200, 250)
# [DEBUG] Match results for Game Screen 1: Min Val=0.3737562298774719 , Max Val=1.0, Min Loc=(1186, 218)
# [DEBUG] Match results for Game Screen 1: Min Val=0.36325085163116455 , Max Val=1.0, Min Loc=(1172, 287)
# [DEBUG] Match results for Game Screen 1: Min Val=0.3352746069431305 , Max Val=1.0, Min Loc=(1159, 257)
# [DEBUG] Match results for Game Screen 1: Min Val=0.3020632565021515 , Max Val=1.0, Min Loc=(1151, 228)
# [DEBUG] Match results for Game Screen 1: Min Val=0.274936705827713 , Max Val=1.0, Min Loc=(1133, 205)
# [DEBUG] Match results for Game Screen 1: Min Val=0.23187166452407837 , Max Val=1.0, Min Loc=(1115, 177)
# [DEBUG] Match results for Game Screen 1: Min Val=0.28519701957702637 , Max Val=1.0, Min Loc=(1099, 155)
# [DEBUG] Match results for Game Screen 1: Min Val=0.38222041726112366 , Max Val=1.0, Min Loc=(1084, 140)
# [DEBUG] Match results for Game Screen 1: Min Val=0.45776838064193726 , Max Val=1.0, Min Loc=(1070, 98)
# [DEBUG] Minimum threshold: 0.23187166452407837
# [INFO] 'R' key pressed. Searching for the game window...
# [DEBUG] Match results for Game Screen 1: Min Val=0.22251267731189728 , Max Val=1.0, Min Loc=(1254, 504)
# [DEBUG] Match results for Game Screen 1: Min Val=0.213132843375206 , Max Val=1.0, Min Loc=(1243, 481)
# [DEBUG] Match results for Game Screen 1: Min Val=0.21890956163406372 , Max Val=1.0, Min Loc=(1230, 455)
# [DEBUG] Match results for Game Screen 1: Min Val=0.22893261909484863 , Max Val=1.0, Min Loc=(1223, 426)
# [DEBUG] Match results for Game Screen 1: Min Val=0.20774486660957336 , Max Val=1.0, Min Loc=(1185, 335)
# [DEBUG] Match results for Game Screen 1: Min Val=0.2002241015434265 , Max Val=1.0, Min Loc=(1171, 306)
# [DEBUG] Match results for Game Screen 1: Min Val=0.18894995748996735 , Max Val=1.0, Min Loc=(1157, 271)
# [DEBUG] Match results for Game Screen 1: Min Val=0.16904202103614807 , Max Val=1.0, Min Loc=(1145, 233)
# [DEBUG] Match results for Game Screen 1: Min Val=0.144515261054039 , Max Val=1.0, Min Loc=(1130, 209)
# [DEBUG] Match results for Game Screen 1: Min Val=0.10025457292795181 , Max Val=1.0, Min Loc=(1114, 177)
# [DEBUG] Match results for Game Screen 1: Min Val=0.15422239899635315 , Max Val=1.0, Min Loc=(1098, 156)
# [DEBUG] Match results for Game Screen 1: Min Val=0.25194695591926575 , Max Val=1.0, Min Loc=(1084, 155)
# [DEBUG] Match results for Game Screen 1: Min Val=0.31820642948150635 , Max Val=1.0, Min Loc=(1060, 160)
# [DEBUG] Minimum threshold: 0.10025457292795181
# [INFO] 'Q' key pressed. Exiting...
# [INFO] Script terminated.
